# %% [markdown]
# <h4><b>Scatter_Plot Function</b></h4>
#
# <ul>
#   <li>The selected code defines a function called <code>plot_scatter</code> that creates a scatter plot with specific characteristics.</li>
#
#   <li><b>Parameters:</b>
#     <ul>
#       <li><code>ax</code>: A matplotlib axes object where the scatter plot will be drawn.</li>
#       <li><code>prng</code>: A random number generator (likely a NumPy random generator).</li>
#       <li><code>nb_samples</code>: Number of samples to plot (default is 100).</li>
#     </ul>
#   </li>
#
#   <li><b>Loop through tuples:</b> The function iterates through a list of tuples, each containing:
#     <ul>
#       <li><code>mu</code>: The mean (location) for the normal distribution.</li>
#       <li><code>sigma</code>: The standard deviation (scale) for the normal distribution.</li>
#       <li><code>marker</code>: The marker style for the scatter plot (e.g., 'o' for circles, 's' for squares).</li>
#     </ul>
#   </li>
#
#   <li><b>For each tuple:</b>
#     <ul>
#       <li>Generates random <code>x</code> and <code>y</code> coordinates using a normal distribution with the specified <code>mu</code> and <code>sigma</code>.</li>
#       <li>Plots these points on the axes with no connecting lines (<code>ls='none'</code>) and the specified marker style.</li>
#     </ul>
#   </li>
#
#   <li>After the loop, the function sets the x-axis label to <b>"X-label"</b>.</li>
#
#   <li>The function returns the modified <code>ax</code> object.</li>
#
#   <li><b>Important Note:</b> The <code>plt.show()</code> line is indented incorrectly and would not execute as part of the function.</li>
# </ul>
#
# <h3>✅ Version of the Function</h3>
#
# <pre>
# <code class="language-python">
# import matplotlib.pyplot as plt
# import numpy as np
#
# def plot_scatter(ax, prng, nb_samples=100):
#     for mu, sigma, marker in [(0, 1, 'o'), (1, 2, 's')]:
#         x = mu + sigma * prng.randn(nb_samples)
#         y = mu + sigma * prng.randn(nb_samples)
#         ax.plot(x, y, ls='none', marker=marker)
#
#     ax.set_xlabel("X-label")
#     return ax
#
# # <b>Example usage</b>
# prng = np.random.RandomState(42)
# fig, ax = plt.subplots()
# plot_scatter(ax, prng)
# plt.show()
# </code>
# </pre>

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_scatter(ax, prng, nb_samples=100):
    for mu, sigma, marker in [(0, 1, 'o'), (1, 2, 's')]:
        x = mu + sigma * prng.randn(nb_samples)
        y = mu + sigma * prng.randn(nb_samples)
        ax.plot(x, y, ls='none', marker=marker)

    ax.set_xlabel("X-label")
    return ax

# %% [markdown]
# <h2>Explanation of the Scatter Plot Code</h2>
#
# <ul>
#   <li><code>prng = np.random.RandomState(42)</code>
#     <ul>
#       <li>Creates a random number generator with a seed value of <b>42</b>.</li>
#       <li>Using a fixed seed ensures reproducible random numbers.</li>
#     </ul>
#   </li>
#
#   <li><code>fig, ax = plt.subplots()</code>
#     <ul>
#       <li>Creates a new Matplotlib figure.</li>
#       <li>Initializes a single subplot (axis object) for plotting.</li>
#     </ul>
#   </li>
#
#   <li><code>plot_scatter(ax, prng)</code>
#     <ul>
#       <li>Calls a function named <code>plot_scatter</code>.</li>
#       <li>This function presumably creates a scatter plot on the given axis using the random number generator.</li>
#     </ul>
#   </li>
#
#   <li><code>plt.show()</code>
#     <ul>
#       <li>Displays the figure with the generated scatter plot.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>Summary</h3>
# <p>
# The code demonstrates how to create a <b>basic scatter plot</b> with reproducible random data
# by combining a fixed-seed random number generator and a custom plotting function.
# </p>

# %%
prng = np.random.RandomState(42)
fig, ax = plt.subplots()
plot_scatter(ax, prng)
plt.show()

# %% [markdown]
# <h3>Scatter Plot Interpretation</h3>
#
# <p>This scatter plot displays two distinct datasets, one represented by <b style="color:blue;">blue circles</b> and the other by <b style="color:orange;">orange squares</b>. The primary takeaway is that while both datasets are centered around the same point, they have vastly different spreads.</p>
#
# <h3>Key Observations</h3>
# <ul>
#   <li><b>Shared Center:</b>
#     Both the blue circles and the orange squares are clustered around the origin <code>(0,0)</code>.
#     <br>➡ This indicates that both datasets have a similar mean or central tendency.
#   </li>
#
#   <li><b>Different Spreads (Variance):</b>
#     The most significant difference between the two datasets is their variance (how spread out the data points are).
#     <ul>
#       <li><b style="color:blue;">Blue Circles (Low Variance):</b> Tightly packed in a dense cloud around the center, representing a dataset with <b>low variance</b>.</li>
#       <li><b style="color:orange;">Orange Squares (High Variance):</b> More widely dispersed, representing a dataset with <b>high variance</b>.</li>
#     </ul>
#   </li>
#
#   <li><b>Significant Overlap:</b>
#     The two datasets overlap considerably, especially in the central region where the blue circles are concentrated.
#     <br>➡ This means you cannot draw a simple line to cleanly separate the two groups.
#   </li>
# </ul>
#
# <h3>Conclusion 📊</h3>
# <p>
# In essence, this plot compares two distributions that share a common center but differ greatly in their spread.
# <br><b style="color:blue;">Blue circles</b> → Predictable, low-variance process.
# <br><b style="color:orange;">Orange squares</b> → More erratic, high-variance process.
# </p>
